# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/home/user/Desktop/ML/Daniel_impedance/run10.csv')

# %%
df
# Out:
#         Wall time   Step         Value
# 0    1.678259e+09     20   1300.980835
# 1    1.678259e+09     40   1298.382812
# 2    1.678259e+09     60   1296.511719
# 3    1.678259e+09     80   1307.585327
# 4    1.678259e+09    100   1309.886963
# ..            ...    ...           ...
# 495  1.678278e+09   9920  39259.523438
# 496  1.678278e+09   9940  39259.523438
# 497  1.678278e+09   9960  38889.238281
# 498  1.678278e+09   9980  38519.191406
# 499  1.678278e+09  10000  38889.394531
#
# [500 rows x 3 columns]

# %%
plt.figure()
plt.plot(df.Step, df.Value,label='Average Reward')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.axhline(y=40000, color='r', linestyle='--',label='Maximal Reward')
plt.legend()
plt.grid()
plt.show()
